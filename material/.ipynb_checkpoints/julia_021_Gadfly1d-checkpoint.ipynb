# %% [markdown]
# # Julia 基礎圖表繪製: Gadfly 一維資料圖表

# %% [markdown]
# 本範例需要使用到的套件有 RDatasets、Gadfly、Cairo、Fontconfig，請在執行以下範例前先安裝。
#
# ```
# ] add RDatasets
# ] add Gadfly
# ] add Cairo
# ] add Fontconfig
# ```

# %% [markdown]
# http://gadflyjl.org/stable/man/backends/#

# %% [markdown]
# ## 讀取資料

# %%
using RDatasets
iris = dataset("datasets", "iris")
# Out:
# 150×5 DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species      │
# │     │ Float64     │ Float64    │ Float64     │ Float64    │ Categorical… │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼──────────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ setosa       │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ setosa       │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ setosa       │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ setosa       │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ setosa       │
# │ 6   │ 5.4         │ 3.9        │ 1.7         │ 0.4        │ setosa       │
# │ 7   │ 4.6         │ 3.4        │ 1.4         │ 0.3        │ setosa       │
# │ 8   │ 5.0         │ 3.4        │ 1.5         │ 0.2        │ setosa       │
# │ 9   │ 4.4         │ 2.9        │ 1.4         │ 0.2        │ setosa       │
# ...

# %% [markdown]
# ## 直方圖

# %%
using Pkg
Pkg.add("Gadfly")
# Out:
#    Updating registry at `C:\Users\HSI\.julia\registries\General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
#   Resolving package versions...
#   Installed Ogg_jll ──────────────── v1.3.4+0
#   Installed Loess ────────────────── v0.5.1
#   Installed KernelDensity ────────── v0.5.1
#   Installed ArrayInterface ───────── v2.8.7
#   Installed BinaryProvider ───────── v0.5.9
#   Installed DataStructures ───────── v0.17.15
#   Installed DiffResults ──────────── v1.0.2
#   Installed DecFP ────────────────── v0.4.8
#   Installed DataAPI ──────────────── v1.3.0
#   Installed Compat ───────────────── v2.2.0
#   Installed CommonSubexpressions ─── v0.2.0
#   Installed RecipesBase ──────────── v1.0.1
#   Installed CoupledFields ────────── v0.1.0
#   Installed StatsBase ────────────── v0.32.2
#   Installed OrderedCollections ───── v1.2.0
#   Installed Media ────────────────── v0.5.0
#   Installed DiffRules ────────────── v1.0.1
# ...

# %%
Pkg.add(["Cairo","Fontconfig"])
# Out:
#   Resolving package versions...
#   Installed Xorg_libX11_jll ─────────── v1.6.9+2
#   Installed Expat_jll ───────────────── v2.2.7+1
#   Installed Libiconv_jll ────────────── v1.16.0+2
#   Installed XSLT_jll ────────────────── v1.1.33+2
#   Installed Gettext_jll ─────────────── v0.20.1+2
#   Installed libpng_jll ──────────────── v1.6.37+3
#   Installed HarfBuzz_jll ────────────── v2.6.1+5
#   Installed Libuuid_jll ─────────────── v2.34.0+4
#   Installed Pixman_jll ──────────────── v0.38.4+2
#   Installed Fontconfig ──────────────── v0.4.0
#   Installed Libffi_jll ──────────────── v3.2.1+1
#   Installed Xorg_libXext_jll ────────── v1.3.4+2
#   Installed Xorg_xtrans_jll ─────────── v1.4.0+1
#   Installed Xorg_libXdmcp_jll ───────── v1.1.3+2
#   Installed Xorg_libXau_jll ─────────── v1.0.9+2
#   Installed Pango_jll ───────────────── v1.42.4+8
#   Installed Xorg_libxcb_jll ─────────── v1.13.0+2
#   Installed Xorg_libpthread_stubs_jll ─ v0.1.0+1
# ...

# %%
using Gadfly
import Cairo, Fontconfig  # 要儲存成 png 格式需要
# Out:
# ┌ Info: Precompiling Cairo [159f3aea-2a34-519c-b102-8c37f9878175]
# └ @ Base loading.jl:1260
# ┌ Info: Precompiling Fontconfig [186bb1d3-e1f7-5a2c-a377-96d770f13627]
# └ @ Base loading.jl:1260

# %%
Geom
# Out:
# Gadfly.Geom

# %%
typeof(Col.value(1))
# Out:
# Gadfly.Col.GroupedColumnValue

# %%
cm
# Out:
# 10.0mm

# %%
typeof(cm)
# Out:
# Measures.Length{:mm,Float64}

# %%
p = plot(iris, x="SepalWidth", Geom.histogram)
# Out:
# Plot(...)

# %%
draw(PNG("histogram.png", 12cm, 9cm), p)

# %% [markdown]
# ## 條狀圖

# %%
chest = dataset("HistData", "ChestSizes") # an exemplary dataset from RDataset
p = plot(chest, x="Chest", y="Count", Geom.bar)
# Out:
# Plot(...)

# %%
draw(PNG("bar.png", 12cm, 9cm), p)

# %% [markdown]
# ## 線圖

# %%
longley = dataset("datasets", "longley")
p = plot(longley, x="Year", y="Employed", Geom.line)
# Out:
# Plot(...)

# %%
draw(PNG("line.png", 12cm, 9cm), p)

# %% [markdown]
# ## 盒狀圖

# %%
p = plot(iris, x="Species", y="SepalWidth", Geom.boxplot) # x has to be categorical, y has to be continuous
# Out:
# Plot(...)

# %%
draw(PNG("boxplot.png", 12cm, 9cm), p)

# %% [markdown]
# ## Violin plot

# %%
p = plot(iris, x="Species", y="SepalWidth", Geom.violin) # x has to be categorical, y has to be continuous
# Out:
# Plot(...)

# %%
draw(PNG("violin.png", 12cm, 9cm), p)
