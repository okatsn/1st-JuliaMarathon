# %% [markdown]
# # Julia 基礎圖表繪製：Gadfly 一維資料圖表
#
# ## 作業 021

# %% [markdown]
# 1. 比較看看盒狀圖與 violin plot 在同樣的資料上分別展現資料的什麼特性。

# %% [markdown]
# 2. 同樣的資料可以以條狀圖或是線圖繪製，思考兩者在表現資料上的特點。

# %%
using RDatasets
# Out:
# ┌ Info: Precompiling RDatasets [ce6b1742-4840-55fa-b093-852dadbb1d8b]
# └ @ Base loading.jl:1260

# %%
using Gadfly
# Out:
# ┌ Info: Precompiling Gadfly [c91e804a-d5a3-530f-b6f0-dfbca275c004]
# └ @ Base loading.jl:1260

# %%
iris = dataset("datasets", "iris")
first(iris,5)
# Out:
# 5×5 DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species      │
# │     │ Float64     │ Float64    │ Float64     │ Float64    │ Categorical… │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼──────────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ setosa       │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ setosa       │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ setosa       │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ setosa       │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ setosa       │

# %%
p = plot(iris,x="Species",y="PetalWidth",Geom.boxplot)
# Out:
# Plot(...)

# %%
p = plot(iris,x="Species",y="PetalWidth",Geom.violin)
# Out:
# Plot(...)

# %%
chest = dataset("HistData", "ChestSizes") # an exemplary dataset from RDataset
# Out:
# 16×2 DataFrame
# │ Row │ Chest │ Count │
# │     │ Int64 │ Int64 │
# ├─────┼───────┼───────┤
# │ 1   │ 33    │ 3     │
# │ 2   │ 34    │ 18    │
# │ 3   │ 35    │ 81    │
# │ 4   │ 36    │ 185   │
# │ 5   │ 37    │ 420   │
# │ 6   │ 38    │ 749   │
# │ 7   │ 39    │ 1073  │
# │ 8   │ 40    │ 1079  │
# │ 9   │ 41    │ 934   │
# │ 10  │ 42    │ 658   │
# │ 11  │ 43    │ 370   │
# │ 12  │ 44    │ 92    │
# │ 13  │ 45    │ 50    │
# │ 14  │ 46    │ 21    │
# │ 15  │ 47    │ 4     │
# │ 16  │ 48    │ 1     │

# %%
p = plot(chest, x="Chest", y="Count", Geom.bar)
# Out:
# Plot(...)

# %%
p = plot(chest, x="Chest", y="Count", Geom.line)
# Out:
# Plot(...)
